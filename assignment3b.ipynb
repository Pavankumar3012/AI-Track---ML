# %% [markdown]
# <a href="https://colab.research.google.com/github/Pavankumar3012/AI-Track---ML/blob/master/assignment3b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x_o = 2
y_o = 3
eta = 0.01
eps = 0.000001
del_x = 1
del_y = 1
max_iters = 1000
iters = 0


def deriv(x,y):
  x_deriv = 6*(x)
  y_deriv = -5*(2.71**-y)
  return x_deriv,y_deriv

while max(abs(del_x), abs(del_y)) > eps and iters < max_iters:
  prev_x = x_o
  prev_y = y_o
  del_x, del_y = deriv(prev_x, prev_y)
  del_x = -eta * del_x
  del_y = -eta * del_y
  x_o = x_o + del_x
  y_o = y_o + del_y
  iters = iters + 1
  print("Iteration", iters, "\nX value is", x_o,"\nY value is", y_o)
print("The local minimum occurs at", x_o,y_o)
# Out:
# Iteration 1
# X value is 1.88
# Y value is 3.0025122458166207
# Iteration 2
# X value is 1.7671999999999999
# Y value is 3.0050244916332414
# Iteration 3
# X value is 1.661168
# Y value is 3.007536737449862
# Iteration 4
# X value is 1.5614979199999999
# Y value is 3.0100489832664827
# Iteration 5
# X value is 1.4678080448
# Y value is 3.0125612290831034
# Iteration 6
# X value is 1.3797395621119999
# Y value is 3.015073474899724
# Iteration 7
# X value is 1.29695518838528
# Y value is 3.017585720716345
# Iteration 8
# X value is 1.219137877082163
# Y value is 3.0200979665329655
# Iteration 9
# X value is 1.1459896044572333
# Y value is 3.022610212349586
# Iteration 10
# X value is 1.0772302281897992
# Y value is 3.025122458166207
# Iteration 11
# X value is 1.0125964144984112
# Y value is 3.0276347039828275
# Iteration 12
# X value is 0.9518406296285066
# Y value is 3.030146949799448
# Iteration 13
# X value is 0.8947301918507962
# Y value is 3.032659195616069
# Iteration 14
# ...
